# %%
# !pip install super-gradients
# !pip install imutils

# !pip install roboflow

# !pip install pytube --upgrade
# Out:
# Collecting super-gradients
#   Downloading super_gradients-3.6.0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (2.1.2)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (4.66.1)
# Requirement already satisfied: boto3>=1.17.15 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (1.26.100)
# Requirement already satisfied: jsonschema>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (4.20.0)
# Requirement already satisfied: Deprecated>=1.2.11 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (1.2.14)
# Requirement already satisfied: scipy>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (1.11.4)
# Requirement already satisfied: matplotlib>=3.3.4 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (3.7.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (5.9.3)
# Requirement already satisfied: tensorboard>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (2.15.1)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (69.0.3)
# Collecting coverage~=5.3.1 (from super-gradients)
#   Downloading coverage-5.3.1.tar.gz (684 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.5/684.5 kB 16.7 MB/s eta 0:00:00
# done
# Requirement already satisfied: torchvision>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (0.16.2)
# Collecting sphinx~=4.0.2 (from super-gradients)
#   Downloading Sphinx-4.0.3-py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.10/site-packages (from super-gradients) (0.2.4)
# Collecting torchmetrics==0.8 (from super-gradients)
#   Downloading torchmetrics-0.8.0-py3-none-any.whl (408 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.6/408.6 kB 25.2 MB/s eta 0:00:00
# Collecting hydra-core>=1.2.0 (from super-gradients)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.8 MB/s eta 0:00:00
# Collecting omegaconf (from super-gradients)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.1 MB/s eta 0:00:00
# Collecting onnxruntime==1.13.1 (from super-gradients)
#   Downloading onnxruntime-1.13.1-cp310-cp310-manylinux_2_27_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 70.9 MB/s eta 0:00:00
# Collecting onnx==1.13.0 (from super-gradients)
#   Downloading onnx-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (9.5.0)
# Collecting pip-tools>=6.12.1 (from super-gradients)
#   Downloading pip_tools-7.3.0-py3-none-any.whl.metadata (23 kB)
# Collecting pyparsing==2.4.5 (from super-gradients)
#   Downloading pyparsing-2.4.5-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 3.9 MB/s eta 0:00:00
# Collecting einops==0.3.2 (from super-gradients)
#   Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Collecting pycocotools==2.0.6 (from super-gradients)
#   Downloading pycocotools-2.0.6.tar.gz (24 kB)
# done
# done
# done
# Requirement already satisfied: protobuf==3.20.3 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (3.20.3)
# Collecting treelib==1.6.1 (from super-gradients)
#   Downloading treelib-1.6.1.tar.gz (24 kB)
# done
# Collecting termcolor==1.1.0 (from super-gradients)
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# done
# Requirement already satisfied: packaging>=20.4 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (21.3)
# Requirement already satisfied: wheel>=0.38.0 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (0.42.0)
# Requirement already satisfied: pygments>=2.7.4 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (2.17.2)
# Collecting stringcase>=1.2.0 (from super-gradients)
#   Downloading stringcase-1.2.0.tar.gz (3.0 kB)
# done
# Collecting numpy<=1.23 (from super-gradients)
#   Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 79.0 MB/s eta 0:00:00
# Requirement already satisfied: rapidfuzz in /opt/conda/lib/python3.10/site-packages (from super-gradients) (3.6.1)
# Collecting json-tricks==3.16.1 (from super-gradients)
#   Downloading json_tricks-3.16.1-py2.py3-none-any.whl (27 kB)
# Collecting onnxsim<1.0,>=0.4.3 (from super-gradients)
#   Downloading onnxsim-0.4.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting data-gradients~=0.3.1 (from super-gradients)
#   Downloading data_gradients-0.3.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: albumentations~=1.3 in /opt/conda/lib/python3.10/site-packages (from super-gradients) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /opt/conda/lib/python3.10/site-packages (from onnx==1.13.0->super-gradients) (4.9.0)
# Collecting coloredlogs (from onnxruntime==1.13.1->super-gradients)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime==1.13.1->super-gradients) (23.5.26)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime==1.13.1->super-gradients) (1.12)
# Collecting pyDeprecate==0.3.* (from torchmetrics==0.8->super-gradients)
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from treelib==1.6.1->super-gradients) (0.18.3)
# Requirement already satisfied: scikit-image>=0.16.1 in /opt/conda/lib/python3.10/site-packages (from albumentations~=1.3->super-gradients) (0.22.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from albumentations~=1.3->super-gradients) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from albumentations~=1.3->super-gradients) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from albumentations~=1.3->super-gradients) (4.9.0.80)
# Collecting botocore<1.30.0,>=1.29.100 (from boto3>=1.17.15->super-gradients)
#   Downloading botocore-1.29.165-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.17.15->super-gradients) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.17.15->super-gradients) (0.6.2)
# Requirement already satisfied: platformdirs>=2.5.2 in /opt/conda/lib/python3.10/site-packages (from data-gradients~=0.3.1->super-gradients) (4.1.0)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (from data-gradients~=0.3.1->super-gradients) (4.9.0.80)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from data-gradients~=0.3.1->super-gradients) (0.12.2)
# Collecting xhtml2pdf==0.2.11 (from data-gradients~=0.3.1->super-gradients)
#   Downloading xhtml2pdf-0.2.11.tar.gz (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.3/108.3 kB 6.8 MB/s eta 0:00:00
# done
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from data-gradients~=0.3.1->super-gradients) (3.1.2)
# Collecting imagededup (from data-gradients~=0.3.1->super-gradients)
#   Downloading imagededup-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 10.8 MB/s eta 0:00:00
# Collecting arabic-reshaper>=3.0.0 (from xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: html5lib>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (1.1)
# Collecting pyHanko>=0.12.1 (from xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading pyHanko-0.21.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting pyhanko-certvalidator>=0.19.5 (from xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading pyhanko_certvalidator-0.26.3-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pypdf>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (4.0.0)
# Requirement already satisfied: python-bidi>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (0.4.2)
# Collecting reportlab<4,>=3.5.53 (from xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading reportlab-3.6.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 66.2 MB/s eta 0:00:00
# Collecting svglib>=1.2.1 (from xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading svglib-1.5.1.tar.gz (913 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.9/913.9 kB 35.7 MB/s eta 0:00:00
# done
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from Deprecated>=1.2.11->super-gradients) (1.14.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.2.0->super-gradients)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.7 MB/s eta 0:00:00
# done
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.2.0->super-gradients) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.2.0->super-gradients) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.2.0->super-gradients) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.2.0->super-gradients) (0.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients) (2.8.2)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from onnxsim<1.0,>=0.4.3->super-gradients) (13.7.0)
# Collecting build (from pip-tools>=6.12.1->super-gradients)
#   Downloading build-1.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: click>=8 in /opt/conda/lib/python3.10/site-packages (from pip-tools>=6.12.1->super-gradients) (8.1.7)
# Requirement already satisfied: pip>=22.2 in /opt/conda/lib/python3.10/site-packages (from pip-tools>=6.12.1->super-gradients) (23.3.2)
# Requirement already satisfied: tomli in /opt/conda/lib/python3.10/site-packages (from pip-tools>=6.12.1->super-gradients) (2.0.1)
# Collecting sphinxcontrib-applehelp (from sphinx~=4.0.2->super-gradients)
#   Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp (from sphinx~=4.0.2->super-gradients)
#   Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath (from sphinx~=4.0.2->super-gradients)
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-htmlhelp (from sphinx~=4.0.2->super-gradients)
#   Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml (from sphinx~=4.0.2->super-gradients)
#   Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl.metadata (2.4 kB)
# Collecting sphinxcontrib-qthelp (from sphinx~=4.0.2->super-gradients)
#   Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl.metadata (2.2 kB)
# Collecting docutils<0.18,>=0.14 (from sphinx~=4.0.2->super-gradients)
#   Downloading docutils-0.17.1-py2.py3-none-any.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.5/575.5 kB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: snowballstemmer>=1.1 in /opt/conda/lib/python3.10/site-packages (from sphinx~=4.0.2->super-gradients) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.10/site-packages (from sphinx~=4.0.2->super-gradients) (2.14.0)
# Collecting alabaster<0.8,>=0.7 (from sphinx~=4.0.2->super-gradients)
#   Downloading alabaster-0.7.16-py3-none-any.whl.metadata (2.9 kB)
# Collecting imagesize (from sphinx~=4.0.2->super-gradients)
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: requests>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from sphinx~=4.0.2->super-gradients) (2.31.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients) (3.5.2)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients) (3.0.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients) (3.13.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients) (3.2.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients) (2023.12.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.100->boto3>=1.17.15->super-gradients) (1.26.18)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super-gradients) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super-gradients) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super-gradients) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->super-gradients) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->data-gradients~=0.3.1->super-gradients) (2.1.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /opt/conda/lib/python3.10/site-packages (from qudida>=0.0.4->albumentations~=1.3->super-gradients) (1.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.5.0->sphinx~=4.0.2->super-gradients) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.5.0->sphinx~=4.0.2->super-gradients) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.5.0->sphinx~=4.0.2->super-gradients) (2023.11.17)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations~=1.3->super-gradients) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations~=1.3->super-gradients) (2023.12.9)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations~=1.3->super-gradients) (0.3)
# Collecting pyproject_hooks (from build->pip-tools>=6.12.1->super-gradients)
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime==1.13.1->super-gradients)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.10/site-packages (from imagededup->data-gradients~=0.3.1->super-gradients) (1.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->onnxsim<1.0,>=0.4.3->super-gradients) (3.0.0)
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.10/site-packages (from seaborn->data-gradients~=0.3.1->super-gradients) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime==1.13.1->super-gradients) (1.3.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.0.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (0.5.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->onnxsim<1.0,>=0.4.3->super-gradients) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn->data-gradients~=0.3.1->super-gradients) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn->data-gradients~=0.3.1->super-gradients) (2023.4)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->super-gradients) (0.5.1)
# Collecting asn1crypto>=1.5.1 (from pyHanko>=0.12.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading asn1crypto-1.5.1-py2.py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 kB 7.5 MB/s eta 0:00:00
# Collecting qrcode>=7.3.1 (from pyHanko>=0.12.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading qrcode-7.4.2-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: tzlocal>=4.3 in /opt/conda/lib/python3.10/site-packages (from pyHanko>=0.12.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (5.2)
# Requirement already satisfied: cryptography>=41.0.5 in /opt/conda/lib/python3.10/site-packages (from pyHanko>=0.12.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (41.0.7)
# Collecting oscrypto>=1.1.0 (from pyhanko-certvalidator>=0.19.5->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading oscrypto-1.3.0-py2.py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.6/194.6 kB 11.8 MB/s eta 0:00:00
# Collecting uritools>=3.0.1 (from pyhanko-certvalidator>=0.19.5->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading uritools-4.0.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->super-gradients) (3.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations~=1.3->super-gradients) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations~=1.3->super-gradients) (3.2.0)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from svglib>=1.2.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (5.1.0)
# Requirement already satisfied: tinycss2>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from svglib>=1.2.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (1.2.1)
# Collecting cssselect2>=0.2.0 (from svglib>=1.2.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading cssselect2-0.7.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=41.0.5->pyHanko>=0.12.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (1.16.0)
# Collecting pypng (from qrcode>=7.3.1->pyHanko>=0.12.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients)
#   Downloading pypng-0.20220715.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=41.0.5->pyHanko>=0.12.1->xhtml2pdf==0.2.11->data-gradients~=0.3.1->super-gradients) (2.21)
# Downloading super_gradients-3.6.0-py3-none-any.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 85.4 MB/s eta 0:00:00
# Downloading data_gradients-0.3.2-py3-none-any.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.5/459.5 kB 25.1 MB/s eta 0:00:00
# Downloading onnxsim-0.4.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 69.5 MB/s eta 0:00:00
# Downloading pip_tools-7.3.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 3.7 MB/s eta 0:00:00
# Downloading alabaster-0.7.16-py3-none-any.whl (13 kB)
# Downloading botocore-1.29.165-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 94.9 MB/s eta 0:00:00
# Downloading build-1.0.3-py3-none-any.whl (18 kB)
# Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 7.4 MB/s eta 0:00:00
# Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 5.3 MB/s eta 0:00:00
# Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 6.1 MB/s eta 0:00:00
# Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 5.8 MB/s eta 0:00:00
# Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 6.2 MB/s eta 0:00:00
# Downloading pyHanko-0.21.0-py3-none-any.whl (433 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.2/433.2 kB 26.1 MB/s eta 0:00:00
# Downloading pyhanko_certvalidator-0.26.3-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 6.8 MB/s eta 0:00:00
# Downloading uritools-4.0.2-py3-none-any.whl (10 kB)
# Building wheels for collected packages: pycocotools, termcolor, treelib, coverage, xhtml2pdf, antlr4-python3-runtime, stringcase, svglib
# done
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp310-cp310-linux_x86_64.whl size=109344 sha256=313d3b358c56dde4467d459fcc6e60a35c2f3bcfe85a907993cc6cd32ba47157
#   Stored in directory: /root/.cache/pip/wheels/58/e6/f9/f87c8f8be098b51b616871315318329cae12cdb618f4caac93
# done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=9f7bf8475aa81a8d54b95abdcac3968ccc76f493927f18659224c9cde00fb109
#   Stored in directory: /root/.cache/pip/wheels/a1/49/46/1b13a65d8da11238af9616b00fdde6d45b0f95d9291bac8452
# done
#   Created wheel for treelib: filename=treelib-1.6.1-py3-none-any.whl size=18369 sha256=0f3a68fd4b6eb7893ebc96ff9ce24267362b55539ac6861cbd0c6d3ca47d7372
#   Stored in directory: /root/.cache/pip/wheels/63/72/8b/76569b82bf280a03c4e294c3b29ee2398217186369c427ed4b
# done
#   Created wheel for coverage: filename=coverage-5.3.1-cp310-cp310-linux_x86_64.whl size=210099 sha256=763798bec844c3f237b3c94ecc20f8c1b6bd0bfaa560248840114abd9b2ef7a0
#   Stored in directory: /root/.cache/pip/wheels/e2/70/10/313be697f460d6024cfa94b7f0e22ffc1c53aab718fb4f42af
# done
#   Created wheel for xhtml2pdf: filename=xhtml2pdf-0.2.11-py3-none-any.whl size=262937 sha256=a0274e87b538f7c94f8c64d8b7041e2b49d234b8a1c31b5f92491928ec4405db
#   Stored in directory: /root/.cache/pip/wheels/72/77/fb/e473c11c4e30a7680bf5b1b7f1d07ef04932184a2f39118e8d
# done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=cea0da1f34082ad41a310855936825c78891fb6e7c8d95c8fd1c344fdf1c8465
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3569 sha256=9ed56dcf250e0abdd168792e4d5280808e448237b648c718df6d4b1cbb167585
#   Stored in directory: /root/.cache/pip/wheels/31/ba/22/1a2d952a9ce8aa86e42fda41e2c87fdaf20e238c88bf8df013
# done
#   Created wheel for svglib: filename=svglib-1.5.1-py3-none-any.whl size=30903 sha256=444df14a0d178fb94783851232708cd02eed26ba74e6c84cb78e4d0075e26daa
#   Stored in directory: /root/.cache/pip/wheels/56/9f/90/f37f4b9dbf82987a24ae14f15586e96715cb669a4710b3b85d
# Successfully built pycocotools termcolor treelib coverage xhtml2pdf antlr4-python3-runtime stringcase svglib
# Installing collected packages: termcolor, stringcase, pypng, json-tricks, einops, asn1crypto, arabic-reshaper, antlr4-python3-runtime, uritools, treelib, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, reportlab, qrcode, pyproject_hooks, pyparsing, pyDeprecate, oscrypto, omegaconf, numpy, imagesize, humanfriendly, docutils, coverage, alabaster, onnx, cssselect2, coloredlogs, botocore, torchmetrics, svglib, sphinx, pyhanko-certvalidator, onnxsim, onnxruntime, hydra-core, build, pyHanko, pycocotools, pip-tools, imagededup, xhtml2pdf, data-gradients, super-gradients
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.4.0
#     Uninstalling termcolor-2.4.0:
#       Successfully uninstalled termcolor-2.4.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.20.1
#     Uninstalling docutils-0.20.1:
#       Successfully uninstalled docutils-0.20.1
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.15.0
#     Uninstalling onnx-1.15.0:
#       Successfully uninstalled onnx-1.15.0
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.22
#     Uninstalling botocore-1.34.22:
#       Successfully uninstalled botocore-1.34.22
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 1.3.0.post0
#     Uninstalling torchmetrics-1.3.0.post0:
#       Successfully uninstalled torchmetrics-1.3.0.post0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# aiobotocore 2.11.0 requires botocore<1.34.23,>=1.33.2, but you have botocore 1.29.165 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# chex 0.1.85 requires numpy>=1.24.1, but you have numpy 1.23.0 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.3.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# cuml 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# dask-cuda 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.8.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.23.0 which is incompatible.
# pylibraft 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.3.0 which is incompatible.
# pytoolconfig 1.3.1 requires packaging>=23.2, but you have packaging 21.3 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# raft-dask 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# rmm 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.3.0 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# tensorflowjs 4.16.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# xarray 2024.1.0 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# Successfully installed alabaster-0.7.16 antlr4-python3-runtime-4.9.3 arabic-reshaper-3.0.0 asn1crypto-1.5.1 botocore-1.29.165 build-1.0.3 coloredlogs-15.0.1 coverage-5.3.1 cssselect2-0.7.0 data-gradients-0.3.2 docutils-0.17.1 einops-0.3.2 humanfriendly-10.0 hydra-core-1.3.2 imagededup-0.3.2 imagesize-1.4.1 json-tricks-3.16.1 numpy-1.23.0 omegaconf-2.3.0 onnx-1.13.0 onnxruntime-1.13.1 onnxsim-0.4.35 oscrypto-1.3.0 pip-tools-7.3.0 pyDeprecate-0.3.2 pyHanko-0.21.0 pycocotools-2.0.6 pyhanko-certvalidator-0.26.3 pyparsing-2.4.5 pypng-0.20220715.0 pyproject_hooks-1.0.0 qrcode-7.4.2 reportlab-3.6.13 sphinx-4.0.3 sphinxcontrib-applehelp-1.0.8 sphinxcontrib-devhelp-1.0.6 sphinxcontrib-htmlhelp-2.0.5 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.7 sphinxcontrib-serializinghtml-1.1.10 stringcase-1.2.0 super-gradients-3.6.0 svglib-1.5.1 termcolor-1.1.0 torchmetrics-0.8.0 treelib-1.6.1 uritools-4.0.2 xhtml2pdf-0.2.11
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
# done
# Building wheels for collected packages: imutils
# done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25834 sha256=c7ad38e1d93353c538faa2e6f3bd8d4b3d6b5f3a64fe4b1cbab1d4ec78f83f10
#   Stored in directory: /root/.cache/pip/wheels/85/cf/3a/e265e975a1e7c7e54eb3692d6aa4e2e7d6a3945d29da46f2d7
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# Collecting roboflow
#   Downloading roboflow-1.1.18-py3-none-any.whl.metadata (9.3 kB)
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 5.3 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from roboflow) (3.7.4)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.23.0)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from roboflow) (9.5.0)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.18.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: urllib3>=1.26.6 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.26.18)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /opt/conda/lib/python3.10/site-packages (from roboflow) (0.10.1)
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (4.47.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (2.4.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from supervision->roboflow) (0.7.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from supervision->roboflow) (1.11.4)
# Downloading roboflow-1.1.18-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 4.7 MB/s eta 0:00:00
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.7 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 34.2 MB/s eta 0:00:00
# Downloading supervision-0.18.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: python-magic, opencv-python-headless, idna, cycler, chardet, certifi, supervision, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab 4.0.11 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.2 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.8.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# tensorflowjs 4.16.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 python-magic-0.4.27 roboflow-1.1.18 supervision-0.18.0
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %% [markdown]
# # importing Liberys

# %%
import torch
from super_gradients.training import Trainer
# Out:
# The console stream is logged into /root/sg_logs/console.log
# [2024-02-01 08:44:19] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# [2024-02-01 08:44:20] WARNING - __init__.py - Failed to import pytorch_quantization
# [2024-02-01 08:44:20] INFO - utils.py - NumExpr defaulting to 4 threads.
# 2024-02-01 08:44:25.804764: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-01 08:44:25.804880: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-01 08:44:25.922016: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [2024-02-01 08:44:37] WARNING - calibrator.py - Failed to import pytorch_quantization
# [2024-02-01 08:44:37] WARNING - export.py - Failed to import pytorch_quantization
# [2024-02-01 08:44:37] WARNING - selective_quantization_utils.py - Failed to import pytorch_quantization

# %%
CHECKPOINT_DIR = 'checkpoints'
trainer = Trainer(experiment_name='yolonas_run', ckpt_root_dir=CHECKPOINT_DIR)

# %%
from super_gradients.training import dataloaders
from super_gradients.training.dataloaders.dataloaders import coco_detection_yolo_format_train, coco_detection_yolo_format_val

# %% [markdown]
# # set params

# %%
dataset_params = {
    'data_dir':'/kaggle/input/aquarium-data-cots/aquarium_pretrain',
    'train_images_dir':'train/images',
    'train_labels_dir':'train/labels',
    'val_images_dir':'valid/images',
    'val_labels_dir':'valid/labels',
    'test_images_dir':'test/images',
    'test_labels_dir':'test/labels',
    'classes': ['fish', 'jellyfish', 'penguin', 'puffin', 'shark', 'starfish', 'stingray']
}

# %% [markdown]
# # convert Data to Coco yolo format

# %%
from IPython.display import clear_output

train_data = coco_detection_yolo_format_train(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['train_images_dir'],
        'labels_dir': dataset_params['train_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size':16,
        'num_workers':2
    }
)

val_data = coco_detection_yolo_format_val(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['val_images_dir'],
        'labels_dir': dataset_params['val_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size':16,
        'num_workers':2
    }
)

test_data = coco_detection_yolo_format_val(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['test_images_dir'],
        'labels_dir': dataset_params['test_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size':16,
        'num_workers':2
    }
)

clear_output()
# Out:
# Indexing dataset annotations: 100%|██████████| 63/63 [00:00<00:00, 101.14it/s]

# %% [markdown]
# # Plot some images

# %%
train_data.dataset.plot()

# %% [markdown]
# # getting yolo nas Model

# %%
from super_gradients.training import models
model = models.get('yolo_nas_l', 
                   num_classes=len(dataset_params['classes']), 
                   pretrained_weights="coco"
                   )
# Out:
# [2024-02-01 08:44:50] INFO - checkpoint_utils.py - License Notification: YOLO-NAS pre-trained weights are subjected to the specific license terms and conditions detailed in
# https://github.com/Deci-AI/super-gradients/blob/master/LICENSE.YOLONAS.md
# By downloading the pre-trained weight files you agree to comply with these terms.
# Downloading: "https://sghub.deci.ai/models/yolo_nas_l_coco.pth" to /root/.cache/torch/hub/checkpoints/yolo_nas_l_coco.pth
# 100%|██████████| 256M/256M [00:00<00:00, 271MB/s]
# [2024-02-01 08:44:52] INFO - checkpoint_utils.py - Successfully loaded pretrained weights for architecture yolo_nas_l

# %% [markdown]
# # set training and val params

# %%
from super_gradients.training.losses import PPYoloELoss
from super_gradients.training.metrics import DetectionMetrics_050
from super_gradients.training.models.detection_models.pp_yolo_e import PPYoloEPostPredictionCallback

train_params = {
    # ENABLING SILENT MODE
    'silent_mode': True,
    "average_best_models":True,
    "warmup_mode": "linear_epoch_step",
    "warmup_initial_lr": 1e-6,
    "lr_warmup_epochs": 3,
    "initial_lr": 5e-4,
    "lr_mode": "cosine",
    "cosine_final_lr_ratio": 0.1,
    "optimizer": "Adam",
    "optimizer_params": {"weight_decay": 0.0001},
    "zero_weight_decay_on_bias_and_bn": True,
    "ema": True,
    "ema_params": {"decay": 0.9, "decay_type": "threshold"},
    # ONLY TRAINING FOR 10 EPOCHS FOR THIS EXAMPLE NOTEBOOK
    "max_epochs": 10,
    "mixed_precision": True,
    "loss": PPYoloELoss(
        use_static_assigner=False,
        # NOTE: num_classes needs to be defined here
        num_classes=len(dataset_params['classes']),
        reg_max=16
    ),
    "valid_metrics_list": [
        DetectionMetrics_050(
            score_thres=0.1,
            top_k_predictions=300,
            # NOTE: num_classes needs to be defined here
            num_cls=len(dataset_params['classes']),
            normalize_targets=True,
            post_prediction_callback=PPYoloEPostPredictionCallback(
                score_threshold=0.01,
                nms_top_k=1000,
                max_predictions=300,
                nms_threshold=0.7
            )
        )
    ],
    "metric_to_watch": 'mAP@0.50'
}

# %% [markdown]
# # Training yolo nas Model

# %%
trainer.train(model=model, 
              training_params=train_params, 
              train_loader=train_data, 
              valid_loader=val_data)
# Out:
# [2024-02-01 08:44:52] INFO - sg_trainer.py - Starting a new run with `run_id=RUN_20240201_084452_755726`
# [2024-02-01 08:44:52] INFO - sg_trainer.py - Checkpoints directory: checkpoints/yolonas_run/RUN_20240201_084452_755726
# [2024-02-01 08:44:52] INFO - sg_trainer.py - Using EMA with params {'decay': 0.9, 'decay_type': 'threshold'}
# The console stream is now moved to checkpoints/yolonas_run/RUN_20240201_084452_755726/console_Feb01_08_44_52.txt
# /opt/conda/lib/python3.10/site-packages/super_gradients/common/registry/registry.py:72: DeprecationWarning: Object name `linear_epoch_step` is now deprecated. Please replace it with `LinearEpochLRWarmup`.
#   warnings.warn(f"Object name `{name}` is now deprecated. Please replace it with `{deprecated_names[name]}`.", DeprecationWarning)
# /opt/conda/lib/python3.10/site-packages/super_gradients/training/utils/optimizer_utils.py:108: DeprecationWarning: initialize_param_groups and update_param_groups usages are deprecated since 3.4.0, will be removed in 3.5.0 and have no effect.
#  Assign different learning rates by passing a mapping of layer name prefixes to lr values through initial_lr training hyperparameter (i.e initial_lr={'backbone': 0.01, 'default':0.1})
#   warnings.warn(
# [2024-02-01 08:44:57] INFO - sg_trainer_utils.py - TRAINING PARAMETERS:
#     - Mode:                         Single GPU
#     - Number of GPUs:               1          (1 available on the machine)
#     - Full dataset size:            447        (len(train_set))
#     - Batch size per GPU:           16         (batch_size)
#     - Batch Accumulate:             1          (batch_accumulate)
#     - Total batch size:             16         (num_gpus * batch_size)
#     - Effective Batch size:         16         (num_gpus * batch_size * batch_accumulate)
#     - Iterations per epoch:         27         (len(train_loader))
#     - Gradient updates per epoch:   27         (len(train_loader) / batch_accumulate)
#     - Model: YoloNAS_L  (66.91M parameters, 66.91M optimized)
#     - Learning Rates and Weight Decays:
#       - default: (66.91M parameters). LR: 0.0005 (66.91M parameters) WD: 0.0, (84.70K parameters), WD: 0.0001, (66.83M parameters)
#
# [2024-02-01 08:45:40] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:45:40] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.0005954386433586478
# [2024-02-01 08:46:21] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:46:21] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.12568940222263336
# [2024-02-01 08:47:12] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:47:12] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.23120161890983582
# [2024-02-01 08:48:05] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:48:05] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.3213937282562256
# [2024-02-01 08:48:58] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:48:58] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.3523626923561096
# [2024-02-01 08:49:50] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:49:50] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.4276018440723419
# [2024-02-01 08:50:47] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:50:47] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.5418615341186523
# [2024-02-01 08:51:43] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:51:43] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.6387345194816589
# [2024-02-01 08:52:40] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:52:40] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.6427358984947205
# [2024-02-01 08:53:39] INFO - base_sg_logger.py - Checkpoint saved in checkpoints/yolonas_run/RUN_20240201_084452_755726/ckpt_best.pth
# [2024-02-01 08:53:39] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.6653605103492737
# [2024-02-01 08:53:57] INFO - sg_trainer.py - RUNNING ADDITIONAL TEST ON THE AVERAGED MODEL...
# Validating epoch 10: 100%|██████████| 8/8 [00:04<00:00,  1.91it/s]

# %% [markdown]
# # Get and load trained checkpoints

# %%
import os

checkpoint_path=os.path.join(trainer.checkpoints_dir_path, "ckpt_best.pth")

# %%
best_model = models.get('yolo_nas_l',
                        num_classes=len(dataset_params['classes']),
                        checkpoint_path=checkpoint_path)

# %% [markdown]
# # testing model

# %%
trainer.test(model=best_model,
            test_loader=test_data,
            test_metrics_list=DetectionMetrics_050(score_thres=0.1, 
                                                   top_k_predictions=300, 
                                                   num_cls=len(dataset_params['classes']), 
                                                   normalize_targets=True, 
                                                   post_prediction_callback=PPYoloEPostPredictionCallback(score_threshold=0.01, 
                                                                                                          nms_top_k=1000, 
                                                                                                          max_predictions=300,                                                                              
                                                                                                          nms_threshold=0.7)
                                                  ))
# Out:
# Testing:  75%|███████▌  | 3/4 [00:02<00:00,  1.43it/s]
# {'PPYoloELoss/loss_cls': 0.8907405,
#  'PPYoloELoss/loss_iou': 0.5136306,
#  'PPYoloELoss/loss_dfl': 0.46887177,
#  'PPYoloELoss/loss': 1.8732429,
#  'Precision@0.50': 0.04672028869390488,
#  'Recall@0.50': 0.9161564707756042,
#  'mAP@0.50': 0.6998118162155151,
#  'F1@0.50': 0.0878794714808464,
#  'Best_score_threshold': 0.5600000023841858}

# %% [markdown]
# # Testing and plot one image

# %%
img="/kaggle/input/aquarium-data-cots/aquarium_pretrain/test/images/IMG_2319_jpeg_jpg.rf.6e20bf97d17b74a8948aa48776c40454.jpg"
best_model.predict(img).show()
# Out:
# [2024-02-01 08:54:09] INFO - pipelines.py - Fusing some of the model's layers. If this takes too much memory, you can deactivate it by setting `fuse_model=False`
# /opt/conda/lib/python3.10/site-packages/super_gradients/training/utils/visualization/utils.py:67: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap("gist_rainbow", num_classes)
